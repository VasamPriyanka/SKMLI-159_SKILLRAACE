# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import keras
import tensorflow as tf

ipl = pd.read_csv('/content/sample_data/ipl_data.csv')
ipl.head()
# Out:
#    mid        date               bat_team                    bowl_team  \
# 0    1  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 1    1  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 2    1  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 3    1  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore
# 4    1  18-04-2008  Kolkata Knight Riders  Royal Challengers Bangalore
#
#        batsman   bowler  runs  wickets  overs  runs_last_5  wickets_last_5  \
# 0   SC Ganguly  P Kumar     1        0    0.1            1               0
# 1  BB McCullum  P Kumar     1        0    0.2            1               0
# 2  BB McCullum  P Kumar     2        0    0.2            2               0
# 3  BB McCullum  P Kumar     2        0    0.3            2               0
# 4  BB McCullum  P Kumar     2        0    0.4            2               0
#
#    striker  non-striker  total
# 0        0            0    222
# 1        0            0    222
# 2        0            0    222
# 3        0            0    222
# 4        0            0    222

# %%
#Dropping certain features
df = ipl.drop(['date', 'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5','mid', 'striker', 'non-striker'], axis =1)

X = df.drop(['total'], axis =1)
y = df['total']

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object for each categorical feature and Fit the categorical features with label encoding
batting_team_encoder = LabelEncoder()
bowling_team_encoder = LabelEncoder()
striker_encoder = LabelEncoder()
bowler_encoder = LabelEncoder()
X['bat_team'] = batting_team_encoder.fit_transform(X['bat_team'])
X['bowl_team'] = bowling_team_encoder.fit_transform(X['bowl_team'])
X['batsman'] = striker_encoder.fit_transform(X['batsman'])
X['bowler'] = bowler_encoder.fit_transform(X['bowler'])

# %%
# Train test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
# Fit the scaler on the training data and transform both training and testing data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the neural network model and Compile the model with Huber loss
model = keras.Sequential([
    keras.layers.Input( shape=(X_train_scaled.shape[1],)),  # Input layer
    keras.layers.Dense(512, activation='relu'),  # Hidden layer with 512 units and ReLU activation
    keras.layers.Dense(216, activation='relu'),  # Hidden layer with 216 units and ReLU activation
    keras.layers.Dense(1, activation='linear')  # Output layer with linear activation for regression
])

huber_loss = tf.keras.losses.Huber(delta=1.0)  # You can adjust the 'delta' parameter as needed
model.compile(optimizer='adam', loss=huber_loss)  # Use Huber loss for regression

# %%
model.fit(X_train_scaled, y_train, epochs=25, batch_size=64, validation_data=(X_test_scaled, y_test))
# Out:
# Epoch 1/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 56.8889 - val_loss: 22.1652
# Epoch 2/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 22.6891 - val_loss: 22.5750
# Epoch 3/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 22.4490 - val_loss: 22.1461
# Epoch 4/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 22.4462 - val_loss: 22.3116
# Epoch 5/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 22.4176 - val_loss: 22.2083
# Epoch 6/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 22.4386 - val_loss: 22.1686
# Epoch 7/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 22.4734 - val_loss: 22.1308
# Epoch 8/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 22.3264 - val_loss: 22.1581
# Epoch 9/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - loss: 22.3418 - val_loss: 22.2266
# Epoch 10/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 22.4168 - val_loss: 22.2023
# Epoch 11/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 22.5336 - val_loss: 22.1324
# Epoch 12/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - loss: 22.4454 - val_loss: 22.4370
# Epoch 13/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 22.3772 - val_loss: 22.0885
# Epoch 14/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 22.3799 - val_loss: 22.1046
# Epoch 15/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - loss: 22.4014 - val_loss: 22.2569
# Epoch 16/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 22.3558 - val_loss: 22.2913
# Epoch 17/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 22.4260 - val_loss: 22.0896
# Epoch 18/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 22.3856 - val_loss: 22.1546
# Epoch 19/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - loss: 22.3742 - val_loss: 22.1517
# Epoch 20/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 22.4044 - val_loss: 22.2634
# Epoch 21/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 22.3343 - val_loss: 22.0637
# Epoch 22/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - loss: 22.4513 - val_loss: 22.5791
# Epoch 23/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 22.3347 - val_loss: 22.1458
# Epoch 24/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - loss: 22.2436 - val_loss: 22.1984
# Epoch 25/25
# 832/832 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 22.4203 - val_loss: 22.1770

# %%
model_losses = pd.DataFrame(model.history.history)
model_losses.plot()
# Out:
# <Axes: >

# %%
# Make predictions
predictions = model.predict(X_test_scaled)
from sklearn.metrics import mean_absolute_error,mean_squared_error
mean_absolute_error(y_test,predictions)
# Out:
# 713/713 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 22.671506712850157

# %%
def predict_score():
    #User inputs
    batting_team = input("Enter Batting Team: ")
    bowling_team = input("Enter Bowling Team: ")
    striker = input("Enter Striker: ")
    bowler = input("Enter Bowler: ")

    # Handle unseen labels
    try:
        encoded_batting_team = batting_team_encoder.transform([batting_team])
    except ValueError:
        print(f"Warning: Batting team '{batting_team}' not seen during training. Using a default value.")
        encoded_batting_team = np.array([0]) # Or any other suitable default value

    try:
        encoded_bowling_team = bowling_team_encoder.transform([bowling_team])
    except ValueError:
        print(f"Warning: Bowling team '{bowling_team}' not seen during training. Using a default value.")
        encoded_bowling_team = np.array([0])

    try:
        encoded_striker = striker_encoder.transform([striker])
    except ValueError:
        print(f"Warning: Striker '{striker}' not seen during training. Using a default value.")
        encoded_striker = np.array([0])

    try:
        encoded_bowler = bowler_encoder.transform([bowler])
    except ValueError:
        print(f"Warning: Bowler '{bowler}' not seen during training. Using a default value.")
        encoded_bowler = np.array([0])

    # Prepare the input array
    input_data = np.array([encoded_batting_team[0], encoded_bowling_team[0], encoded_striker[0], encoded_bowler[0]])
    input_data = input_data.reshape(1, -1)

    # Scale the input data
    input_data_scaled = scaler.transform(input_data)

    # Predict the score
    predicted_score = model.predict(input_data_scaled)

    print(f"Predicted Score: {predicted_score[0][0]}")

predict_score()
# Out:
# Enter Batting Team: Sunrisers Hyderabad
# Enter Bowling Team: Mumbai Indians
# Enter Striker: DC Warner
# Enter Bowler: Bumrah
# Warning: Striker 'DC Warner' not seen during training. Using a default value.
# Warning: Bowler 'Bumrah' not seen during training. Using a default value.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted Score: 167.17938232421875
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
